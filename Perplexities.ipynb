# %%
import subprocess

perplexities = subprocess.Popen(["./perplexity.sh", "data/allep", "data/episodes", "LM", "0.75"], cwd="./ngram", stdout=subprocess.PIPE)
sorted_perplexities = subprocess.check_output(["sort", "-k", "2"], stdin=perplexities.stdout)

print(sorted_perplexities)
# Out:
# .DS_Store:      21.85
# s07e14:     208.37
# s07e24:     234.44
# s06e10:     252.64
# s03e14:     266.40
# s06e22:     377.53
# s08e24:     384.58
# s07e05:     409.19
# s06e13:     412.14
# s04e14:     414.15
# s09e04:     421.14
# s07e09:     432.61
# s07e01:     443.36
# s01e06:     445.42
# s07e16:     446.95
# s07e22:     450.51
# s07e19:     451.69
# s09e10:     451.85
# s02e05:     457.43
# s01e05:     461.99
# s08e10:     464.98
# s09e07:     468.12
# s09e05:     469.88
# s07e21:     469.92
# s01e03:     474.39
# s02e13:     474.88
# s09e17:     475.59
# s09e06:     477.15
# s07e18:     477.79
# s02e12:     478.51
# s09e08:     478.60
# s02e22:     478.91
# s08e14:     480.40
# s07e11:     482.40
# s02e14:     485.66
# s06e14:     486.12
# s09e15:     486.24
# s08e13:     489.09
# s03e12:     490.59
# s09e21:     491.61
# s02e09:     494.48
# s02e06:     495.85
# s02e08:     496.56
# s09e12:     497.14
# s07e13:     498.54
# s04e05:     498.65
# s09e02:     500.50
# ...
